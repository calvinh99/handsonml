# %% [markdown]
# # Imports

# %%
# files and paths
import json
from pathlib import Path
import zipfile
import os

# numbers and data
import numpy as np
import pandas as pd
from scipy import sparse
from tqdm.notebook import tqdm

# pandas ops
from pandas.testing import assert_frame_equal

pd.options.display.width = 180
pd.options.display.max_colwidth = 120

# data_dir = Path('../input/AI4Code')

# %% [markdown]
# # The Data

# %% [markdown]
# We need to thoroughly explore the data and understand it.

# %% [markdown]
# ## Dir Paths

# %% [markdown]
# Let's first explore the data directories and paths.

# %%
DATA_DIR = os.path.join(".", "datasets")
EXTRACTED = True

zip_path = os.path.join(DATA_DIR, "AI4Code.zip")
data_path = os.path.join(DATA_DIR, "AI4Code")
if not EXTRACTED:
    with zipfile.ZipFile(zip_path, 'r') as z:
        z.extractall(data_path)

# %% [markdown]
# Now let's convert the AI4Code directory to a Path object.

# %%
data_root = Path(data_path)
data_root
# Out:
# PosixPath('datasets/AI4Code')

# %%
def print_iterdir_indented(root):
    """
    Takes a PosixPath object and prints all sub-dirs and 
    sub-files in a concise manner.
    """
    print(root.resolve(), end="\n\n")
    for curr_dir, sub_dirs, sub_files in os.walk(root):
        n_indents = len(Path(curr_dir).parts) - len(root.parts)
        print("    " * n_indents, Path(curr_dir).name + os.sep) # os.sep is "/"
        for i, f in enumerate(sorted(sub_files)):
            if i > 2:
                print("    " * (n_indents+1), "...")
                break
            print("    " * (n_indents+1), f)

# %%
print_iterdir_indented(data_root)
# Out:
# /Users/calvinhuang/ml/learning/datasets/AI4Code
#
#  AI4Code/
#      sample_submission.csv
#      train_ancestors.csv
#      train_orders.csv
#      test/
#          0009d135ece78d.json
#          0010483c12ba9b.json
#          0010a919d60e4f.json
#          ...
#      train/
#          00001756c60be8.json
#          00015c83e2717b.json
#          0001bdd4021779.json
#          ...

# %% [markdown]
# ## To DataFrame

# %% [markdown]
# Read the json files and convert to dataframes.

# %%
MAX_TRAIN_LEN = 10000

train_root = data_root / "train"
train_paths = list(train_root.glob("*.json"))
len(train_paths)
# Out:
# 139256

# %% [markdown]
# Let's explore the data using a subset for speed.

# %%
train_paths = train_paths[:MAX_TRAIN_LEN]

# %% [markdown]
# Create a function to print the json contents.

# %%
def read_json(path):
    with open(path, mode='r') as stream:
        parsed = json.load(stream)
        print(json.dumps(parsed, indent=4))
# read_json(train_paths[0])

# %% [markdown]
# Create a function to create a pandas df from the json.

# %%
def read_notebook(path):
    return (
        pd.read_json(
            path,
            dtype={'cell_type': 'category', 'source': 'str'})
        .assign(id=path.stem)
        .rename_axis('cell_id')
    )

print(train_paths[0])
read_notebook(train_paths[0])
# Out:
# datasets/AI4Code/train/8f1d0a3e812ccb.json
#          cell_type                                                                                                                   source              id
# cell_id
# 02373f0f      code              import numpy as np \nimport pandas as pd\nimport os\nimport matplotlib.pyplot as plt\nimport seaborn as sns  8f1d0a3e812ccb
# 7eee6f0d      code                                 # training data\ntrain_dts = pd.read_csv('../input/titanic/train.csv')\ntrain_dts.head()  8f1d0a3e812ccb
# e38ca82d      code                                        # test data\ntest_dts = pd.read_csv('../input/titanic/test.csv')\ntest_dts.head()  8f1d0a3e812ccb
# 9376e7b4      code  female = train_dts.loc[train_dts.Sex=='female']['Survived']\nprint('% of Female survived : {:.3f}'.format((sum(femal...  8f1d0a3e812ccb
# dfdb7c2c      code  print('Shape of Training Set : {}'.format(train_dts.shape))\nprint('Number of training data points : {}\n'.format(le...  8f1d0a3e812ccb
# ...            ...                                                                                                                      ...             ...
# 88243368  markdown                                                  after the final processing of features we are remaning with 30 features  8f1d0a3e812ccb
# 604f6956  markdown                                                             Calculating Survival rate of Male and Female on training set  8f1d0a3e812ccb
# 0562b43b  markdown                                                                                 creating titles from names of passengers  8f1d0a3e812ccb
# 4f0494f1  markdown                                        can be seen clearly that female has much larger probablity of surviving then male  8f1d0a3e812ccb
# d1798638  markdown                                                                      # 4. Creating train and test set and label encoding  8f1d0a3e812ccb
#
# [65 rows x 3 columns]

# %% [markdown]
# Now let's read all jsons to pandas dfs.

# %%
notebooks_train = [
    read_notebook(path) for path in tqdm(train_paths, desc='Read train_set')
]
# Out:
# Read train_set:   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
df = (
    pd.concat(notebooks_train)
    .set_index('id', append=True)
    .swaplevel()
    .sort_index(level='id', sort_remaining=False)
)
df
# Out:
#                         cell_type                                                                                                                   source
# id             cell_id
# 0002115f48f982 18281c6c      code  import numpy as np # linear algebra\nimport pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)\nimport ...
#                e3b6b115      code                                                               df = pd.read_csv('../input/metadata_train.csv')\ndf.info()
#                4a044c54      code                                                                                                                df.head()
#                365fe576      code  #let's check if targets are consistent within the same measurement id\ntargets = df.groupby('id_measurement')[['targ...
#                a3188e54      code  sns.countplot(x='target',data=targets)\n# it should be only "1" and "0" but we have cases where target is not consit...
# ...                           ...                                                                                                                      ...
# ffe8d0aa5e7d68 b9f0782a  markdown                                                                                                            ### Modelling
#                3492f280  markdown  Now one of the important step in this task, we know that this is a regression task, previously we seen skewness in o...
#                eea09e6e  markdown  We will made our regression model, now we have come to end our task, in this section we will capture some parameter ...
#                54ffd613  markdown                                                                                                                ### Ridge
#                3c645477  markdown                                                                                                         #### Ridge Model
#
# [453294 rows x 2 columns]

# %% [markdown]
# ## Get Ranks of Cells

# %% [markdown]
# Our target is to correctly rank the code and markdown cells. We are given the code cells in correct order (rank 0 to rank n), but the markdown cells following the code cells are in random shuffled order.

# %% [markdown]
# The correct orders for the training data are in `train_orders.csv`

# %%
df_orders = pd.read_csv(data_root / "train_orders.csv",
                        index_col="id",
                       ).squeeze("columns").str.split()
df_orders
# Out:
# id
# 00001756c60be8    [1862f0a6, 448eb224, 2a9e43d6, 7e2f170a, 038b763d, 77e56113, 2eefe0ef, 1ae087ab, 0beab1cd, 8ffe0b25, 9a78ab76, 0d136...
# 00015c83e2717b    [2e94bd7a, 3e99dee9, b5e286ea, da4f7550, c417225b, 51e3cd89, 2600b4eb, 75b65993, cf195f8b, 25699d02, 72b3201a, f2c75...
# 0001bdd4021779    [3fdc37be, 073782ca, 8ea7263c, 80543cd8, 38310c80, 073e27e5, 015d52a4, ad7679ef, 7fde4f04, 07c52510, 0a1a7a39, 0bcd3...
# 0001daf4c2c76d    [97266564, a898e555, 86605076, 76cc2642, ef279279, df6c939f, 2476da96, 00f87d0a, ae93e8e6, 58aadb1d, d20b0094, 986fd...
# 0002115f48f982                                 [9ec225f0, 18281c6c, e3b6b115, 4a044c54, 365fe576, a3188e54, b3f6e12d, ee7655ca, 84125b7a]
#                                                                            ...
# fffc30d5a0bc46    [09727c0c, ff1ea6a0, ddfef603, a01ce9b3, 3ba953ee, bf92a015, f4a0492a, 095812e6, 53125cfe, aa32a700, 63340e73, 06d8c...
# fffc3b44869198    [978a5137, faa48f03, 28dfb12a, eea2e812, 64fef97c, 4e0d1510, 58e68f2c, 8784e700, 4bd5a4cf, dc14bfec, 2aff7603, 8047d...
# fffc63ff750064    [5015c300, 411b85d9, 8238198c, f4781d1d, b5532930, e1f223e5, e7e67119, 4aaf741d, 7229cce6, a7fa3628, e4c2fa86, 1f8f9...
# fffcd063cda949    [7e6266ad, d8281fc5, d4ffcaef, 3e0e4a47, 21387fc8, cc229f9a, baed9c8b, d1bb21aa, 82979992, 65f95dad, eba4fa9e, c97e2...
# fffe1d764579d5    [1a63248d, 9c3b96a5, 1398a873, 4e2d4c2d, f71c538e, 8b44a5e8, 385dff7a, b8254ef8, 4d0e433e, debc496c, e15ae953, e4d79...
# Name: cell_order, Length: 139256, dtype: object

# %% [markdown]
# Let's get an example notebook to apply unit tests to.

# %%
nb_id = df.index.unique("id")[6] # 7th notebook out of the 10K unique notebooks we got
print('Notebook:', nb_id)

print("The disordered notebook:")
nb = df.loc[nb_id]
with pd.option_context('display.max_rows', None):
    display(nb)
# Out:
# Notebook: 0030ea6c6281ce
# The disordered notebook:
#          cell_type                                                                                                                   source
# cell_id
# b8ff09de      code  # import all packages and set plots to be embedded inline\nimport numpy as np\nimport pandas as pd\nimport matplotli...
# 532dd206      code  # load in the dataset into a pandas dataframe, print statistics\nData = pd.read_csv('../input/prosperloandata/prospe...
# 6d1c9755      code                                                   # high-level overview of data shape and composition\nprint(Data.shape)
# 1d0804d1      code  features = ['LoanOriginalAmount', 'BorrowerAPR', 'BorrowerRate','StatedMonthlyIncome', 'Term', 'ProsperRating (Alpha...
# 0aa598c5      code                                                                                                     selected_data.head()
# ca7507bb      code  sns.displot(\n    data=selected_data.isna().melt(value_name="missing"),\n    y="variable",\n    hue="missing",\n    ...
# c0bc83de      code                                                 # descriptive statistics for numeric variables\nselected_data.describe()
# c74e572f      code  # Convert ProsperRating to an ordered type\nrate_order = ['HR','E','D','C','B','A','AA']\nordered_var = pd.api.types...
# 84f0f7b5      code  \n# Convert  Employment status to an ordered type\nemp_order = ['Employed','Self-employed','Full-time','Part-time','...
# f6aca3f0      code  # The `color_palette()` returns the the current / default palette as a list of RGB tuples. \n# Each tuple consists o...
# 338d3fff      code  # Plot the Employment Status \ntype_order = selected_data['EmploymentStatus'].value_counts().index\nsns.countplot(da...
# f1b45f3b      code  # Plot the Term \ntype_order = selected_data['Term'].value_counts().index\nsns.countplot(data=selected_data, x='Term...
# dab43bb1      code  # Plot the Prosper Rating \ntype_order = selected_data['ProsperRating (Alpha)'].value_counts().index\nsns.countplot(...
# 417570f4      code  plt.subplots(figsize = [14,8])\nplt.subplot(1, 2, 1)\napr_bins = np.arange(selected_data.BorrowerAPR.min(), selected...
# c073655f      code  type_order = selected_data['ProsperScore'].value_counts().index\nsns.countplot(data=selected_data, x='ProsperScore',...
# c6a1b1a7      code  plt.subplots(figsize = [14,8])\ntype_order = selected_data['Occupation'].value_counts().index\ng = sns.countplot(dat...
# cac3040f      code  in_bins = np.arange(selected_data.DebtToIncomeRatio.min(), selected_data.DebtToIncomeRatio.max()+0.01, 0.01)\nplt.hi...
# 6e2a32d0      code  numeric_vars = selected_data.select_dtypes(include='number').columns\ncategoric_vars = ['Term', 'EmploymentStatus', ...
# 02a9bf0a      code  # correlation plot\nplt.figure(figsize = [14, 8])\nsns.heatmap(selected_data[numeric_vars].corr(), annot = True, fmt...
# d6a94f6b      code  # plot matrix: sample 500 loans so that plots are clearer and\n# they render faster\nsamples = np.random.choice(sele...
# acbaba60      code  # plot matrix of numeric features against categorical features.\n\ndef boxgrid(x, y, **kwargs):\n    """ Quick hack ...
# fcf2a41d      code  # Look at relationship between Term and the CreditGrade/ProsperRating(s) and ProsperScore\nplt.figure(figsize=[10,10...
# 1ef9d0c0      code  plt.figure(figsize = [8, 6])\nsns.regplot(data = selected_data, x = 'LoanOriginalAmount', y = 'BorrowerAPR', scatter...
# b8823155      code  plt.figure(figsize = [10, 8])\nsns.countplot(data=selected_data, x='ProsperRating (Alpha)', hue='EmploymentStatus', ...
# 21bbdeda      code  plt.figure(figsize=[8,10])\nplt.subplot(3,1,1)\nsns.violinplot(data=selected_data, x='CreditGrade', y='BorrowerRate'...
# d1a4fd97      code  plt.figure(figsize=[14,8])\nplt.title('rating and the term affect on stated monthly income and loan original amount'...
# 4036d3b7      code  plt.figure(figsize = [10,8])\nsns.pointplot(data = selected_data, x = 'ProsperRating (Alpha)', y = 'BorrowerAPR', hu...
# 34fcf26a      code  # Prosper rating effect on relationship of APR and loan amount\ng=sns.FacetGrid(data=selected_data, aspect=1.2, heig...
# 6001fab0      code  # Create a pointplot to show how the BorrowerRate changes for different loan Terms\n# when split up by ProsperRating...
# 34d808df  markdown                                                      **How All numeric features behavior with All categorical features**
# cef03a21  markdown         Next up, the first predictor variable of interest: Term.\n>**Term**: The length of the loan expressed in months.
# 42586e3f  markdown  ### What is the structure of your dataset?\n\n>The dataset has 113,937 loans with 81 variables on each loan. I will ...
# 6fcdd914  markdown  ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?...
# 06e15743  markdown  ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perf...
# 0f775339  markdown  >Violin plots show the distribution of the different credit risks and the BorrowerRate is that there is a negative c...
# b55bf0d9  markdown                                                     **how Prosper rating effect on relationship of APR and loan amoun?**
# 91cc3103  markdown                                                   **What's pairwise correlations present between features in the data?**
# f7083e87  markdown  >Next up, the first predictor variable of interest: **DebtToIncomeRatio**\n<br/><br/>\n**DebtToIncomeRatio**: The de...
# ed8c466d  markdown  >Both distributions are multimodal which the distributions are a normal distribution than skewed right.\nBorrower Ra...
# 20d321d3  markdown                                                       Next up, the first predictor variable of interest: Prosper Rating.
# 0ced6694  markdown  \n>**ProsperRating (Alpha)**: The Prosper Rating assigned at the time the listing was created between AA - HR.  Appl...
# ff993e7f  markdown                                                                     **How The rating and term affect on Borrower APR ?**
# 41513a1c  markdown  >This seems to not make sense but for every single level of the ProsperRating, the BorrowerRate increases as for lon...
# 4df2ab38  markdown                                                       **What's relation between Loan Original Amount and Borrower APR?**
# 3445255e  markdown  >Looking at the box plots for the distribution of the different credit risks annd the BorrowerRate is that there is ...
# 30074b74  markdown                                                                                                ## Univariate Exploration
# 23e38cc7  markdown  ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of i...
# 0900cb32  markdown  >Interestingly, the borrower APR decreases with the increase of borrow term for people with HR &  C ratings. But for...
# 14d97ad0  markdown                             >Comman borrowers indicate **“Employed”** and **“Full-Time”** as employment status.\n<hr />
# 54f399d6  markdown  >Next up, the first predictor variable of interest: Occupation\n<br/><br/>\nOccupation: The Occupation selected by t...
# 92c651a0  markdown  >BorrowerRate and BorrowerAPR have a great correlation between them, which makes sense since those values for a loan...
# a83634e5  markdown  >This graph observed that at the different sizes of the total loan amount, the borrower's APR has a large distributi...
# 4e376bff  markdown                                                        **What's most common Employment Status in each Prosper Rating ?**
# 3dc29916  markdown                                     # Loan Data from Prosper\n\n<br>\n<center><b>By Abdelrhman Ragab Nady</b></center>\n
# 3afb27cc  markdown  \n## Preliminary Wrangling\n\n>This data set contains 113,937 loans with 81 variables on each loan, including loan a...
# 2de3bd40  markdown  >About stated monthly income, it doesn't seem like there is an interaction effect between term and rating, the patte...
# 2abc895e  markdown  ### Talk about some of the relationships you observed in this part of the investigation. Were there features that st...
# e6ca1c07  markdown  |Occupation          |             frequency|\n| --- | ----- |\n|Computer Programmer   |       4478|\n|Executive    ...
# d9b93c8c  markdown                             **What's relationship between Term and the CreditGrade/ProsperRating(s) and ProsperScore ?**
# 86d90738  markdown  >The distribution of the DebtToIncomeRatio was highly skewed by the presence of those with very high incomes to thei...
# 8c1c8746  markdown  >Lower ratings were noted to have greater proportions of individuals with employment status Not Employed, Self-emplo...
# f425aa62  markdown  >It's observed that degree of risk between **0.4 : 0.8** It's not good but also not bad which the most common rate i...
# c64b4907  markdown  >The loan amount increases with the best rating. The borrower's APR decreases with the best rating. Interestingly, t...
# ded374cd  markdown  >The length of most Common of the loans are 36 months Then it was followed by a long distance of 60 months which the...
# 4e6d7d82  markdown                                                            >The ratings of most common of the borrowers are among C to D
# c5965243  markdown  >Next up, the first predictor variable of interest: ProsperScore<br><br>\n**ProsperScore**: A custom risk score buil...
# 5b4357d9  markdown  \n\nI'll start by looking at the distribution of the main variable of interest: **employment status**.\n\n>**Employm...
# 82a794f1  markdown                     **What's correlation between (CreditGrade, the ProsperRating, and ProsperScore) to BorrowerRate  ?**
# 699baeea  markdown                                                                                    **How Many Missing in the Data Set?**
# 7e8bf4c4  markdown                                                  **How BorrowerRate & ProsperScore behavior with categorical features?**
# aa22eae8  markdown  >Interestingly, it appears that there are some positive relationships between the categorical variables and the two ...
# cb9302de  markdown                   **How the stated monthly income and loan original amount variables effect on ProsperRating (Alpha) ?**
# b0202ee4  markdown  >we have a greatly missed data in **Credit Grade** so maybe result of analysis of this feature isn't accurate, **Pro...
# 892e48fe  markdown  >Finally, let's look at relationships between the three categorical features.<br><br>\n**how the BorrowerRate change...
# 8ea0b9bc  markdown  Next up, the first predictor variable of interest: BorrowerAPR and BorrowerRate\n>**BorrowerAPR** : The Borrower's A...
# 991e1262  markdown  >Because I noted huge variance between highest and lowest counts. I used **Log Scale** in my chart\n<br><br>\nI foun...

# %% [markdown]
# Let's get the correct order of this particular notebook.

# %%
cell_order = df_orders.loc[nb_id]

print("The ordered notebook:")
with pd.option_context("display.max_rows", None):
    display(nb.loc[cell_order])
# Out:
# The ordered notebook:
#          cell_type                                                                                                                   source
# cell_id
# 3dc29916  markdown                                     # Loan Data from Prosper\n\n<br>\n<center><b>By Abdelrhman Ragab Nady</b></center>\n
# 3afb27cc  markdown  \n## Preliminary Wrangling\n\n>This data set contains 113,937 loans with 81 variables on each loan, including loan a...
# b8ff09de      code  # import all packages and set plots to be embedded inline\nimport numpy as np\nimport pandas as pd\nimport matplotli...
# 532dd206      code  # load in the dataset into a pandas dataframe, print statistics\nData = pd.read_csv('../input/prosperloandata/prospe...
# 6d1c9755      code                                                   # high-level overview of data shape and composition\nprint(Data.shape)
# 1d0804d1      code  features = ['LoanOriginalAmount', 'BorrowerAPR', 'BorrowerRate','StatedMonthlyIncome', 'Term', 'ProsperRating (Alpha...
# 0aa598c5      code                                                                                                     selected_data.head()
# 42586e3f  markdown  ### What is the structure of your dataset?\n\n>The dataset has 113,937 loans with 81 variables on each loan. I will ...
# 6fcdd914  markdown  ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?...
# 699baeea  markdown                                                                                    **How Many Missing in the Data Set?**
# ca7507bb      code  sns.displot(\n    data=selected_data.isna().melt(value_name="missing"),\n    y="variable",\n    hue="missing",\n    ...
# b0202ee4  markdown  >we have a greatly missed data in **Credit Grade** so maybe result of analysis of this feature isn't accurate, **Pro...
# c0bc83de      code                                                 # descriptive statistics for numeric variables\nselected_data.describe()
# 30074b74  markdown                                                                                                ## Univariate Exploration
# c74e572f      code  # Convert ProsperRating to an ordered type\nrate_order = ['HR','E','D','C','B','A','AA']\nordered_var = pd.api.types...
# 84f0f7b5      code  \n# Convert  Employment status to an ordered type\nemp_order = ['Employed','Self-employed','Full-time','Part-time','...
# 5b4357d9  markdown  \n\nI'll start by looking at the distribution of the main variable of interest: **employment status**.\n\n>**Employm...
# f6aca3f0      code  # The `color_palette()` returns the the current / default palette as a list of RGB tuples. \n# Each tuple consists o...
# 338d3fff      code  # Plot the Employment Status \ntype_order = selected_data['EmploymentStatus'].value_counts().index\nsns.countplot(da...
# 14d97ad0  markdown                             >Comman borrowers indicate **“Employed”** and **“Full-Time”** as employment status.\n<hr />
# cef03a21  markdown         Next up, the first predictor variable of interest: Term.\n>**Term**: The length of the loan expressed in months.
# f1b45f3b      code  # Plot the Term \ntype_order = selected_data['Term'].value_counts().index\nsns.countplot(data=selected_data, x='Term...
# ded374cd  markdown  >The length of most Common of the loans are 36 months Then it was followed by a long distance of 60 months which the...
# 20d321d3  markdown                                                       Next up, the first predictor variable of interest: Prosper Rating.
# 0ced6694  markdown  \n>**ProsperRating (Alpha)**: The Prosper Rating assigned at the time the listing was created between AA - HR.  Appl...
# dab43bb1      code  # Plot the Prosper Rating \ntype_order = selected_data['ProsperRating (Alpha)'].value_counts().index\nsns.countplot(...
# 4e6d7d82  markdown                                                            >The ratings of most common of the borrowers are among C to D
# 8ea0b9bc  markdown  Next up, the first predictor variable of interest: BorrowerAPR and BorrowerRate\n>**BorrowerAPR** : The Borrower's A...
# 417570f4      code  plt.subplots(figsize = [14,8])\nplt.subplot(1, 2, 1)\napr_bins = np.arange(selected_data.BorrowerAPR.min(), selected...
# ed8c466d  markdown  >Both distributions are multimodal which the distributions are a normal distribution than skewed right.\nBorrower Ra...
# c5965243  markdown  >Next up, the first predictor variable of interest: ProsperScore<br><br>\n**ProsperScore**: A custom risk score buil...
# c073655f      code  type_order = selected_data['ProsperScore'].value_counts().index\nsns.countplot(data=selected_data, x='ProsperScore',...
# f425aa62  markdown  >It's observed that degree of risk between **0.4 : 0.8** It's not good but also not bad which the most common rate i...
# 54f399d6  markdown  >Next up, the first predictor variable of interest: Occupation\n<br/><br/>\nOccupation: The Occupation selected by t...
# c6a1b1a7      code  plt.subplots(figsize = [14,8])\ntype_order = selected_data['Occupation'].value_counts().index\ng = sns.countplot(dat...
# 991e1262  markdown  >Because I noted huge variance between highest and lowest counts. I used **Log Scale** in my chart\n<br><br>\nI foun...
# e6ca1c07  markdown  |Occupation          |             frequency|\n| --- | ----- |\n|Computer Programmer   |       4478|\n|Executive    ...
# f7083e87  markdown  >Next up, the first predictor variable of interest: **DebtToIncomeRatio**\n<br/><br/>\n**DebtToIncomeRatio**: The de...
# cac3040f      code  in_bins = np.arange(selected_data.DebtToIncomeRatio.min(), selected_data.DebtToIncomeRatio.max()+0.01, 0.01)\nplt.hi...
# 86d90738  markdown  >The distribution of the DebtToIncomeRatio was highly skewed by the presence of those with very high incomes to thei...
# 06e15743  markdown  ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perf...
# 6e2a32d0      code  numeric_vars = selected_data.select_dtypes(include='number').columns\ncategoric_vars = ['Term', 'EmploymentStatus', ...
# 91cc3103  markdown                                                   **What's pairwise correlations present between features in the data?**
# 02a9bf0a      code  # correlation plot\nplt.figure(figsize = [14, 8])\nsns.heatmap(selected_data[numeric_vars].corr(), annot = True, fmt...
# 34d808df  markdown                                                      **How All numeric features behavior with All categorical features**
# d6a94f6b      code  # plot matrix: sample 500 loans so that plots are clearer and\n# they render faster\nsamples = np.random.choice(sele...
# 92c651a0  markdown  >BorrowerRate and BorrowerAPR have a great correlation between them, which makes sense since those values for a loan...
# 7e8bf4c4  markdown                                                  **How BorrowerRate & ProsperScore behavior with categorical features?**
# acbaba60      code  # plot matrix of numeric features against categorical features.\n\ndef boxgrid(x, y, **kwargs):\n    """ Quick hack ...
# 3445255e  markdown  >Looking at the box plots for the distribution of the different credit risks annd the BorrowerRate is that there is ...
# d9b93c8c  markdown                             **What's relationship between Term and the CreditGrade/ProsperRating(s) and ProsperScore ?**
# fcf2a41d      code  # Look at relationship between Term and the CreditGrade/ProsperRating(s) and ProsperScore\nplt.figure(figsize=[10,10...
# aa22eae8  markdown  >Interestingly, it appears that there are some positive relationships between the categorical variables and the two ...
# 4df2ab38  markdown                                                       **What's relation between Loan Original Amount and Borrower APR?**
# 1ef9d0c0      code  plt.figure(figsize = [8, 6])\nsns.regplot(data = selected_data, x = 'LoanOriginalAmount', y = 'BorrowerAPR', scatter...
# a83634e5  markdown  >This graph observed that at the different sizes of the total loan amount, the borrower's APR has a large distributi...
# 4e376bff  markdown                                                        **What's most common Employment Status in each Prosper Rating ?**
# b8823155      code  plt.figure(figsize = [10, 8])\nsns.countplot(data=selected_data, x='ProsperRating (Alpha)', hue='EmploymentStatus', ...
# 8c1c8746  markdown  >Lower ratings were noted to have greater proportions of individuals with employment status Not Employed, Self-emplo...
# 82a794f1  markdown                     **What's correlation between (CreditGrade, the ProsperRating, and ProsperScore) to BorrowerRate  ?**
# 21bbdeda      code  plt.figure(figsize=[8,10])\nplt.subplot(3,1,1)\nsns.violinplot(data=selected_data, x='CreditGrade', y='BorrowerRate'...
# 0f775339  markdown  >Violin plots show the distribution of the different credit risks and the BorrowerRate is that there is a negative c...
# 23e38cc7  markdown  ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of i...
# cb9302de  markdown                   **How the stated monthly income and loan original amount variables effect on ProsperRating (Alpha) ?**
# d1a4fd97      code  plt.figure(figsize=[14,8])\nplt.title('rating and the term affect on stated monthly income and loan original amount'...
# 2de3bd40  markdown  >About stated monthly income, it doesn't seem like there is an interaction effect between term and rating, the patte...
# ff993e7f  markdown                                                                     **How The rating and term affect on Borrower APR ?**
# 4036d3b7      code  plt.figure(figsize = [10,8])\nsns.pointplot(data = selected_data, x = 'ProsperRating (Alpha)', y = 'BorrowerAPR', hu...
# 0900cb32  markdown  >Interestingly, the borrower APR decreases with the increase of borrow term for people with HR &  C ratings. But for...
# b55bf0d9  markdown                                                     **how Prosper rating effect on relationship of APR and loan amoun?**
# 34fcf26a      code  # Prosper rating effect on relationship of APR and loan amount\ng=sns.FacetGrid(data=selected_data, aspect=1.2, heig...
# c64b4907  markdown  >The loan amount increases with the best rating. The borrower's APR decreases with the best rating. Interestingly, t...
# 892e48fe  markdown  >Finally, let's look at relationships between the three categorical features.<br><br>\n**how the BorrowerRate change...
# 6001fab0      code  # Create a pointplot to show how the BorrowerRate changes for different loan Terms\n# when split up by ProsperRating...
# 41513a1c  markdown  >This seems to not make sense but for every single level of the ProsperRating, the BorrowerRate increases as for lon...
# 2abc895e  markdown  ### Talk about some of the relationships you observed in this part of the investigation. Were there features that st...

# %% [markdown]
# Our goal is to have a target feature that represents this ordering - a rank value that, when ordered, is ordinal from 0 to n-1 (n is the number of cells).

# %%
def get_ranks(ordered_cells, unordered_cells):
    return [ordered_cells.index(cell_id) 
            for cell_id in unordered_cells]

cell_ranks = get_ranks(cell_order, nb.index)
nb.insert(0, "rank", cell_ranks)
with pd.option_context('display.max_rows', None):
    display(nb)
# Out:
#           rank cell_type                                                                                                                   source
# cell_id
# b8ff09de     2      code  # import all packages and set plots to be embedded inline\nimport numpy as np\nimport pandas as pd\nimport matplotli...
# 532dd206     3      code  # load in the dataset into a pandas dataframe, print statistics\nData = pd.read_csv('../input/prosperloandata/prospe...
# 6d1c9755     4      code                                                   # high-level overview of data shape and composition\nprint(Data.shape)
# 1d0804d1     5      code  features = ['LoanOriginalAmount', 'BorrowerAPR', 'BorrowerRate','StatedMonthlyIncome', 'Term', 'ProsperRating (Alpha...
# 0aa598c5     6      code                                                                                                     selected_data.head()
# ca7507bb    10      code  sns.displot(\n    data=selected_data.isna().melt(value_name="missing"),\n    y="variable",\n    hue="missing",\n    ...
# c0bc83de    12      code                                                 # descriptive statistics for numeric variables\nselected_data.describe()
# c74e572f    14      code  # Convert ProsperRating to an ordered type\nrate_order = ['HR','E','D','C','B','A','AA']\nordered_var = pd.api.types...
# 84f0f7b5    15      code  \n# Convert  Employment status to an ordered type\nemp_order = ['Employed','Self-employed','Full-time','Part-time','...
# f6aca3f0    17      code  # The `color_palette()` returns the the current / default palette as a list of RGB tuples. \n# Each tuple consists o...
# 338d3fff    18      code  # Plot the Employment Status \ntype_order = selected_data['EmploymentStatus'].value_counts().index\nsns.countplot(da...
# f1b45f3b    21      code  # Plot the Term \ntype_order = selected_data['Term'].value_counts().index\nsns.countplot(data=selected_data, x='Term...
# dab43bb1    25      code  # Plot the Prosper Rating \ntype_order = selected_data['ProsperRating (Alpha)'].value_counts().index\nsns.countplot(...
# 417570f4    28      code  plt.subplots(figsize = [14,8])\nplt.subplot(1, 2, 1)\napr_bins = np.arange(selected_data.BorrowerAPR.min(), selected...
# c073655f    31      code  type_order = selected_data['ProsperScore'].value_counts().index\nsns.countplot(data=selected_data, x='ProsperScore',...
# c6a1b1a7    34      code  plt.subplots(figsize = [14,8])\ntype_order = selected_data['Occupation'].value_counts().index\ng = sns.countplot(dat...
# cac3040f    38      code  in_bins = np.arange(selected_data.DebtToIncomeRatio.min(), selected_data.DebtToIncomeRatio.max()+0.01, 0.01)\nplt.hi...
# 6e2a32d0    41      code  numeric_vars = selected_data.select_dtypes(include='number').columns\ncategoric_vars = ['Term', 'EmploymentStatus', ...
# 02a9bf0a    43      code  # correlation plot\nplt.figure(figsize = [14, 8])\nsns.heatmap(selected_data[numeric_vars].corr(), annot = True, fmt...
# d6a94f6b    45      code  # plot matrix: sample 500 loans so that plots are clearer and\n# they render faster\nsamples = np.random.choice(sele...
# acbaba60    48      code  # plot matrix of numeric features against categorical features.\n\ndef boxgrid(x, y, **kwargs):\n    """ Quick hack ...
# fcf2a41d    51      code  # Look at relationship between Term and the CreditGrade/ProsperRating(s) and ProsperScore\nplt.figure(figsize=[10,10...
# 1ef9d0c0    54      code  plt.figure(figsize = [8, 6])\nsns.regplot(data = selected_data, x = 'LoanOriginalAmount', y = 'BorrowerAPR', scatter...
# b8823155    57      code  plt.figure(figsize = [10, 8])\nsns.countplot(data=selected_data, x='ProsperRating (Alpha)', hue='EmploymentStatus', ...
# 21bbdeda    60      code  plt.figure(figsize=[8,10])\nplt.subplot(3,1,1)\nsns.violinplot(data=selected_data, x='CreditGrade', y='BorrowerRate'...
# d1a4fd97    64      code  plt.figure(figsize=[14,8])\nplt.title('rating and the term affect on stated monthly income and loan original amount'...
# 4036d3b7    67      code  plt.figure(figsize = [10,8])\nsns.pointplot(data = selected_data, x = 'ProsperRating (Alpha)', y = 'BorrowerAPR', hu...
# 34fcf26a    70      code  # Prosper rating effect on relationship of APR and loan amount\ng=sns.FacetGrid(data=selected_data, aspect=1.2, heig...
# 6001fab0    73      code  # Create a pointplot to show how the BorrowerRate changes for different loan Terms\n# when split up by ProsperRating...
# 34d808df    44  markdown                                                      **How All numeric features behavior with All categorical features**
# cef03a21    20  markdown         Next up, the first predictor variable of interest: Term.\n>**Term**: The length of the loan expressed in months.
# 42586e3f     7  markdown  ### What is the structure of your dataset?\n\n>The dataset has 113,937 loans with 81 variables on each loan. I will ...
# 6fcdd914     8  markdown  ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?...
# 06e15743    40  markdown  ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perf...
# 0f775339    61  markdown  >Violin plots show the distribution of the different credit risks and the BorrowerRate is that there is a negative c...
# b55bf0d9    69  markdown                                                     **how Prosper rating effect on relationship of APR and loan amoun?**
# 91cc3103    42  markdown                                                   **What's pairwise correlations present between features in the data?**
# f7083e87    37  markdown  >Next up, the first predictor variable of interest: **DebtToIncomeRatio**\n<br/><br/>\n**DebtToIncomeRatio**: The de...
# ed8c466d    29  markdown  >Both distributions are multimodal which the distributions are a normal distribution than skewed right.\nBorrower Ra...
# 20d321d3    23  markdown                                                       Next up, the first predictor variable of interest: Prosper Rating.
# 0ced6694    24  markdown  \n>**ProsperRating (Alpha)**: The Prosper Rating assigned at the time the listing was created between AA - HR.  Appl...
# ff993e7f    66  markdown                                                                     **How The rating and term affect on Borrower APR ?**
# 41513a1c    74  markdown  >This seems to not make sense but for every single level of the ProsperRating, the BorrowerRate increases as for lon...
# 4df2ab38    53  markdown                                                       **What's relation between Loan Original Amount and Borrower APR?**
# 3445255e    49  markdown  >Looking at the box plots for the distribution of the different credit risks annd the BorrowerRate is that there is ...
# 30074b74    13  markdown                                                                                                ## Univariate Exploration
# 23e38cc7    62  markdown  ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of i...
# 0900cb32    68  markdown  >Interestingly, the borrower APR decreases with the increase of borrow term for people with HR &  C ratings. But for...
# 14d97ad0    19  markdown                             >Comman borrowers indicate **“Employed”** and **“Full-Time”** as employment status.\n<hr />
# 54f399d6    33  markdown  >Next up, the first predictor variable of interest: Occupation\n<br/><br/>\nOccupation: The Occupation selected by t...
# 92c651a0    46  markdown  >BorrowerRate and BorrowerAPR have a great correlation between them, which makes sense since those values for a loan...
# a83634e5    55  markdown  >This graph observed that at the different sizes of the total loan amount, the borrower's APR has a large distributi...
# 4e376bff    56  markdown                                                        **What's most common Employment Status in each Prosper Rating ?**
# 3dc29916     0  markdown                                     # Loan Data from Prosper\n\n<br>\n<center><b>By Abdelrhman Ragab Nady</b></center>\n
# 3afb27cc     1  markdown  \n## Preliminary Wrangling\n\n>This data set contains 113,937 loans with 81 variables on each loan, including loan a...
# 2de3bd40    65  markdown  >About stated monthly income, it doesn't seem like there is an interaction effect between term and rating, the patte...
# 2abc895e    75  markdown  ### Talk about some of the relationships you observed in this part of the investigation. Were there features that st...
# e6ca1c07    36  markdown  |Occupation          |             frequency|\n| --- | ----- |\n|Computer Programmer   |       4478|\n|Executive    ...
# d9b93c8c    50  markdown                             **What's relationship between Term and the CreditGrade/ProsperRating(s) and ProsperScore ?**
# 86d90738    39  markdown  >The distribution of the DebtToIncomeRatio was highly skewed by the presence of those with very high incomes to thei...
# 8c1c8746    58  markdown  >Lower ratings were noted to have greater proportions of individuals with employment status Not Employed, Self-emplo...
# f425aa62    32  markdown  >It's observed that degree of risk between **0.4 : 0.8** It's not good but also not bad which the most common rate i...
# c64b4907    71  markdown  >The loan amount increases with the best rating. The borrower's APR decreases with the best rating. Interestingly, t...
# ded374cd    22  markdown  >The length of most Common of the loans are 36 months Then it was followed by a long distance of 60 months which the...
# 4e6d7d82    26  markdown                                                            >The ratings of most common of the borrowers are among C to D
# c5965243    30  markdown  >Next up, the first predictor variable of interest: ProsperScore<br><br>\n**ProsperScore**: A custom risk score buil...
# 5b4357d9    16  markdown  \n\nI'll start by looking at the distribution of the main variable of interest: **employment status**.\n\n>**Employm...
# 82a794f1    59  markdown                     **What's correlation between (CreditGrade, the ProsperRating, and ProsperScore) to BorrowerRate  ?**
# 699baeea     9  markdown                                                                                    **How Many Missing in the Data Set?**
# 7e8bf4c4    47  markdown                                                  **How BorrowerRate & ProsperScore behavior with categorical features?**
# aa22eae8    52  markdown  >Interestingly, it appears that there are some positive relationships between the categorical variables and the two ...
# cb9302de    63  markdown                   **How the stated monthly income and loan original amount variables effect on ProsperRating (Alpha) ?**
# b0202ee4    11  markdown  >we have a greatly missed data in **Credit Grade** so maybe result of analysis of this feature isn't accurate, **Pro...
# 892e48fe    72  markdown  >Finally, let's look at relationships between the three categorical features.<br><br>\n**how the BorrowerRate change...
# 8ea0b9bc    27  markdown  Next up, the first predictor variable of interest: BorrowerAPR and BorrowerRate\n>**BorrowerAPR** : The Borrower's A...
# 991e1262    35  markdown  >Because I noted huge variance between highest and lowest counts. I used **Log Scale** in my chart\n<br><br>\nI foun...

# %% [markdown]
# Sorting by the rank value is the same as ordering the notebook.

# %%
assert_frame_equal(nb.loc[cell_order], nb.sort_values("rank"))

# %% [markdown]
# Let's create our target df - the ranks for each notebook's cells.

# %%
# df with index id and cols cell_order, cell_id
df_orders_ = df_orders.to_frame().join(
    df.reset_index('cell_id').groupby('id')['cell_id'].apply(list),
    how='right',
)

# dict with id: cell_id, rank
ranks = {}
for id_, cell_order, cell_id in df_orders_.itertuples():
    ranks[id_] = {"cell_id": cell_id, "rank": get_ranks(cell_order, cell_id)}
    
# create a df for rank
df_ranks = (
    pd.DataFrame
    .from_dict(ranks, orient="index")
    .rename_axis("id")
    .apply(pd.Series.explode)
    .set_index("cell_id", append=True)
)
df_ranks
# Out:
#                         rank
# id             cell_id
# 0002115f48f982 18281c6c    1
#                e3b6b115    2
#                4a044c54    3
#                365fe576    4
#                a3188e54    5
# ...                      ...
# ffe8d0aa5e7d68 b9f0782a   54
#                3492f280   45
#                eea09e6e   59
#                54ffd613   68
#                3c645477   63
#
# [453294 rows x 1 columns]

# %% [markdown]
# ## Grouping by Ancestor

# %%
df_ancestors = pd.read_csv(data_root / "train_ancestors.csv", index_col="id")
df_ancestors
# Out:
#                ancestor_id       parent_id
# id
# 00001756c60be8    945aea18             NaN
# 00015c83e2717b    aa2da37e  317b65d12af9df
# 0001bdd4021779    a7711fde             NaN
# 0001daf4c2c76d    090152ca             NaN
# 0002115f48f982    272b483a             NaN
# ...                    ...             ...
# fffc30d5a0bc46    6aed207b             NaN
# fffc3b44869198    a6aaa8d7             NaN
# fffc63ff750064    0a1b5b65             NaN
# fffcd063cda949    d971e960             NaN
# fffe1d764579d5    3c40bfa6             NaN
#
# [139256 rows x 2 columns]

# %%
df_ancestors.loc[:, "ancestor_id"].unique()
# Out:
# array(['945aea18', 'aa2da37e', 'a7711fde', ..., '0a1b5b65', 'd971e960',
#        '3c40bfa6'], dtype=object)

# %% [markdown]
# To get a split without leakage (let's say notebooks in the valid set have a common ancestor with notebooks in train set), we need to split each notebook by their ancestors.

# %%
from sklearn.model_selection import GroupShuffleSplit

NVALID = 0.1

splitter = GroupShuffleSplit(n_splits=1, test_size=NVALID, random_state=42)

# split by groups aka ancestors
ids = df.index.unique("id")
ancestors = df_ancestors.loc[ids, "ancestor_id"]
ids_train, ids_valid = next(splitter.split(ids, groups=ancestors))
ids_train, ids_valid = ids[ids_train], ids[ids_valid]

df_train, df_valid = df.loc[ids_train], df.loc[ids_valid]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# We want to extract info from the source. Let's use a tf-idf vectorizer, which will evaluate the relative frequency of words in each cell to all cells.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(min_df=0.01)
X_train = tfidf.fit_transform(df_train.loc[:, "source"].astype(str))
y_train = df_ranks.loc[ids_train].to_numpy()
groups = df_ranks.loc[ids_train].groupby("id").size().to_numpy()

# %%
X_train.shape, y_train.shape, groups.shape
# Out:
# ((408191, 280), (408191, 1), (8998,))

# %% [markdown]
# We want to have the rank values of the code cells, which are ordered, and 0 for markdown cells, which are randomly shuffled.

# %%
X_train = sparse.hstack((
    X_train,
    np.where(
        df_train['cell_type'] == 'code',
        df_train.groupby(['id', 'cell_type']).cumcount().to_numpy() + 1,
        0,
    ).reshape(-1, 1)
))
X_train.shape
# Out:
# (408191, 281)

# %% [markdown]
# # The Model

# %% [markdown]
# Use XGBRanker.

# %%
from xgboost import XGBRanker

model = XGBRanker(
    min_child_weight=10,
    subsample=0.5,
    tree_method='hist',
)
model.fit(X_train, y_train, group=groups)
# Out:
# XGBRanker(base_score=0.5, booster='gbtree', callbacks=None, colsample_bylevel=1,
#           colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=None,
#           enable_categorical=False, eval_metric=None, gamma=0, gpu_id=-1,
#           grow_policy='depthwise', importance_type=None,
#           interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#           max_cat_to_onehot=4, max_delta_step=0, max_depth=6, max_leaves=0,
#           min_child_weight=10, missing=nan, monotone_constraints='()',
#           n_estimators=100, n_jobs=0, num_parallel_tree=1, predictor='auto',
#           random_state=0, reg_alpha=0, reg_lambda=1, ...)

# %% [markdown]
# # Evaluate

# %% [markdown]
# Now we need to evaluate the model's performance on our validation data, since the test set does not have target data available.

# %%
# Validation set
X_valid = tfidf.transform(df_valid['source'].astype(str))
# The metric uses cell ids
y_valid = df_orders.loc[ids_valid]

X_valid = sparse.hstack((
    X_valid,
    np.where(
        df_valid['cell_type'] == 'code',
        df_valid.groupby(['id', 'cell_type']).cumcount().to_numpy() + 1,
        0,
    ).reshape(-1, 1)
))

# %%
X_valid.shape, y_valid.shape
# Out:
# ((45103, 281), (1002,))

# %% [markdown]
# What the model outputs is the ranks of the cells, we need to process so that our y_pred is a list of cell ids.

# %%
y_pred = pd.DataFrame({'rank': model.predict(X_valid)}, index=df_valid.index)

# convert from id, cell_id: rank to id: list of cell_ids in correct order
y_pred = (
    y_pred
    .sort_values(["id", "rank"])
    .reset_index("cell_id")
    .groupby("id")["cell_id"].apply(list)
)
y_pred.shape
# Out:
# (1002,)

# %% [markdown]
# Examine a notebook.

# %%
nb_id = df_valid.index.unique("id")[8]

nb = df.loc[nb_id]
display(nb)
display(nb.loc[y_pred.loc[nb_id]])
# Out:
#          cell_type                                                                                                                   source
# cell_id
# d28db502      code  from math import sqrt\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\nfrom sklearn.metric...
# 79dcd8fe      code  file = '../input/solarpanelspower/PV_Elec_Gas3.csv'\n#../input/solarpanelspower/PV_Elec_Gas3.csv\ndf = pd.read_csv(f...
# 0e4aa042      code  # make a column with the daily power (stationary)\nsolarpower['day_power']=0.0\nfor index in range(solarpower.index[...
# 787fce34      code                           plt.plot(solarpower.day_power)\nplt.xticks(color='aqua')\nplt.yticks(color='aqua')\nplt.show()
# c24871ae      code  '''simple exponential smoothing go back to last N values\n y_t = a * y_t + a * (1-a)^1 * y_t-1 + a * (1-a)^2 * y_t-2...
# db97fa2c      code  # The optimum alpha is 0.2\n'''simple exponential smoothing go back to last N values\n y_t = a * y_t + a * (1-a)^1 *...
# ac4fc8c1      code  plt.figure(figsize=(15,7))\nplt.plot(solarpower.day_power[:730])\nplt.plot(solarpower.smooth_power[:730])\nplt.xtick...
# ac0f6c52      code                                                                                          solarpower= solarpower.dropna()
# dc28d34e      code  #signal autocorrellation on day_power\nx = np.array(solarpower.day_power[:].values)\nacf = []\nfor i in range(1, len...
# 2b30518b      code  #stats autocorrellation day_power \ny = np.array(solarpower.day_power[:].values)\n\nyunbiased = y-np.mean(y)\nynorm ...
# 332db475      code  '''autocorrellation from https://stackoverflow.com/questions/643699/how-can-i-use-np-correlate-to-do-autocorrelation...
# 7e5f7de4      code  '''autocorrellation from https://stackoverflow.com/questions/643699/how-can-i-use-np-correlate-to-do-autocorrelation...
# 009c12f4      code  # simple fft \nFs = 7*365.0;  # sampling rate 7\nTs = 1.0/Fs; # sampling interval\nt = np.arange(0,1,Ts) # time vect...
# c8aef0d7  markdown                                                                                        Exploring the data of solarpower
# 4893359b  markdown  We can see a lot of noise and can try exponential smoothing to filter out the noise. Exponential smoothing is primar...
# 7327c55e  markdown  We see the obvious yearly cycle and a lot of noise on top. If we want to use some neural network based prediction th...
#          cell_type                                                                                                                   source
# cell_id
# d28db502      code  from math import sqrt\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\nfrom sklearn.metric...
# 79dcd8fe      code  file = '../input/solarpanelspower/PV_Elec_Gas3.csv'\n#../input/solarpanelspower/PV_Elec_Gas3.csv\ndf = pd.read_csv(f...
# 0e4aa042      code  # make a column with the daily power (stationary)\nsolarpower['day_power']=0.0\nfor index in range(solarpower.index[...
# 787fce34      code                           plt.plot(solarpower.day_power)\nplt.xticks(color='aqua')\nplt.yticks(color='aqua')\nplt.show()
# ac4fc8c1      code  plt.figure(figsize=(15,7))\nplt.plot(solarpower.day_power[:730])\nplt.plot(solarpower.smooth_power[:730])\nplt.xtick...
# c24871ae      code  '''simple exponential smoothing go back to last N values\n y_t = a * y_t + a * (1-a)^1 * y_t-1 + a * (1-a)^2 * y_t-2...
# db97fa2c      code  # The optimum alpha is 0.2\n'''simple exponential smoothing go back to last N values\n y_t = a * y_t + a * (1-a)^1 *...
# ac0f6c52      code                                                                                          solarpower= solarpower.dropna()
# c8aef0d7  markdown                                                                                        Exploring the data of solarpower
# 2b30518b      code  #stats autocorrellation day_power \ny = np.array(solarpower.day_power[:].values)\n\nyunbiased = y-np.mean(y)\nynorm ...
# dc28d34e      code  #signal autocorrellation on day_power\nx = np.array(solarpower.day_power[:].values)\nacf = []\nfor i in range(1, len...
# 4893359b  markdown  We can see a lot of noise and can try exponential smoothing to filter out the noise. Exponential smoothing is primar...
# 7e5f7de4      code  '''autocorrellation from https://stackoverflow.com/questions/643699/how-can-i-use-np-correlate-to-do-autocorrelation...
# 332db475      code  '''autocorrellation from https://stackoverflow.com/questions/643699/how-can-i-use-np-correlate-to-do-autocorrelation...
# 009c12f4      code  # simple fft \nFs = 7*365.0;  # sampling rate 7\nTs = 1.0/Fs; # sampling interval\nt = np.arange(0,1,Ts) # time vect...
# 7327c55e  markdown  We see the obvious yearly cycle and a lot of noise on top. If we want to use some neural network based prediction th...

# %% [markdown]
# ## Evaluation Metric

# %% [markdown]
# The competition uses the Kendall tau correlation.
